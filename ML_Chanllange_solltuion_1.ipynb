# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelDuriy228/Yandex_ML_Challange/blob/main/ML_Chanllange_solltuion_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ssh-keygen -t rsa -b 4096 -C "ii256018@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:/0ZXYb73kOTdUfZ8JVh8a/SGMSM2TvaFVYkvGmMP8rg ii256018@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |             +oo=|
# |            B.B=*|
# |           = +=@B|
# |         . =..+*B|
# |        S = *oo==|
# |         o o..=.+|
# |          o. . .o|
# |         E ..   .|
# |           ..    |
# +----[SHA256]-----+

# %%
# !git config --global user.email "ii256018@gmail.com"
# !git config --global user.name "PavelDuriy"

# %%
# !git clone https://github.com/PavelDuriy228/Yandex_ML_Challange.git
# Out:
# Cloning into 'Yandex_ML_Challange'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 4.04 KiB | 4.04 MiB/s, done.

# %%
# !cp -f ML_Challange_sollution_1.ipynb /Yandex_ML_Challange/
# Out:
# cp: cannot stat 'ML_Challange_sollution_1.ipynb': No such file or directory

# %%
with open('known_hosts', 'w', encoding='utf-8') as f:
    f.write("github.com ssh-rsa ... ii256018@gmail.com")

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls
# Out:
# drive  sample_data
